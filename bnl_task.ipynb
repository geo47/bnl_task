# %% [markdown]
# # **Task**
#
# An assistant program will take natural language text as input and call the suitable function with specified parameters or do the correct calculations. Select one of the following tasks.
#
# ### **TASK #1**
# ```python
# sam_measure(name="sample1", exposure_time=10, angle=[0.1])
# ```
#
# This function triggers the hardware to measure the sample for 10 seconds (0.5s or more is reasonable) at a sample tilt angle theta of 0.1 degree (up to 0.5 degree, can be a list e.g. [0.1, 0.2] for measuring at multiple thetas). Both the time and angle are required parameters, sample/material name is optional.
#
# Example inputs:
# *  "I want to measure this polymer sample for ten seconds at an incident angle of 0.1 degree"
#
# *  "Collect data for this material. Let us do an exposure time of 10 seconds and incident angles at 0.1 and 0.2 degree".
#
# *  "We want to look at this perovskite sample to understand its structure. We think 5 seconds of exposure should be sufficient. Theta of 0.2 would be good."
#
#
#
# ### **TASK #2**
#
# Given that
# ```
# d = 2π / q
# q = 4π sin(θ) / λ
# ```
#
# Example inputs:
# *  "For structure with d spacing of 6, what is the corresponding q in the reciprocal/Fourier space?"
#
# *  "When we have q peak of 1, what is the d spacing?"
#
# *  "If q is 1, and the wavelength lambda λ is 1, what is the scattering angle θ in degree? What is the d spacing?"
#
#
# ### **TASK #3**
# Assume that the data reduction step (i.e. data processing, data analysis protocol, result) is defined as summation over a 2D array (i e. image, scattering data, collected/acquired data, measurement).
#
# ```python
# def data_reduction(image, dim=0):
#     curve_1d = sum(array_2d, dim)
#     return curve_1d
# ```
#
# Example inputs:
# "Show us the result for the latest measurement"
# "Run data analysis"
# "Process the latest data"
#
#
# NOTE:
# 1. All information can be given in one NL text paragraph.
# 2. (Optional) Not all information/parameter are given at once, follow up questions by the assistant program are needed.
# 3. Open source model (e.g. Llama2, BERT) preferred
# 4. Working code is preferred, or provide the thought process and methods/reference

# %% [markdown]
# # **Task Submission:** This Notebook contains the working code, implementation description of task 1 and task 2, and further thoughts to build a real-time system with improved performance and accuracy.

# %% [markdown]
# I have worked on `Task #1` and `Task #2`.
#
# Due to the lack of training datasets and fine-tuned models for the specific task, it was really hard to build a robust and well-generalized model.
#
# I used examples given in tasks 1 and 2 as seed examples and generated around 50 synthesized samples. The dataset can be found [here](https://github.com/geo47/bnl_task/tree/master/TaskRecognition/dataset).
#
# ### Task 1:
#
# For task 1, I implement a goal-oriented assistant, whose goal is to recognize user intent and extract required entities to call a function (ex. sample name, exposure time, incident angle) from natural text query.
#
# The steps of the task implementation are briefly defined as follows:
# 1. [Annotate dataset](https://github.com/geo47/bnl_task/tree/master/TaskRecognition/dataset/raw_files) for intent & entities (used task examples)
# 2. Train a [T5-base](https://arxiv.org/pdf/1910.10683.pdf) model on annotated dataset for Feature extraction.
#
# Features includes ```(intent:["task1", "task2"], entities:["sample_name", "exposure_time", "angle"])```
#
# Given a user query:
# - The program first recognizes the intent (Type of task).
# - If the intent is `'task_1'`, it will then pass on to the assistant, who asks for the required entity to perform the hardware operation job.
#
#
# ### Task 2:
#
# I fine-tuned a `Llama-2-7b-chat-hf` model on `14 data samples` created from given examples in task 2. Due to hardware resource limitations in my notebook, I used colab for Task 2 and used T4 GPU _*(free session)*_.
#
# ### Task 2 Colab URL
# `https://colab.research.google.com/drive/1v_vbcmsYiUP_RzkHGFYUZqwU4TJavFy5`
#
# The steps of the task implementation are briefly defined as follows:
# 1. [Annotate dataset](https://colab.research.google.com/drive/1v_vbcmsYiUP_RzkHGFYUZqwU4TJavFy5#scrollTo=sV0D2rjRbk4z) for in instruction based format required to train a llama model (used task examples)
# 2. Train a [Llama-2-7b-chat-hf](https://huggingface.co/meta-llama/Llama-2-7b-chat-hf) model on annotated dataset for Maths operation
#
# ```json
# {
#   "instruction": "Given eq 1: d=2π/q, and eq 2: q=4πsin(θ)/λ, For structure with d spacing of 6, what is the corresponding q in the reciprocal/Fourier space?",
#   "input": "",
#   "output": "Given a spacing d=6, the corresponding q can be calculated with eq 1: d=2π/q:\nsubstitute the value of d in eq 1: 6=2π/q\nNow, solve for q:\nq=2π/6\nSimplify:\nq=π/3\n\nSo, if a material exhibits a spacing between crystal lattice planes d of 6, this corresponds to a reciprocal/Fourier space scattering vector q of π/3."
# }
# ```
# Given a user query:
# - The program first recognizes the intent (Type of task).
# - If the intent is `'task_2'`, it will then pass on to the Llama assistant to perform the calculations.

# %% [markdown]
# ### **Install Dependencies and restart Runtime**

# %%
# !pip install langchain transformers datasets nltk pytorch-lightning==1.5.9 pip torchtext==0.6.0 seqeval

# %%
# Dependencies for training and using Llama2 model.
# !pip uninstall -y tensorflow --quiet
# !pip install ludwig ludwig[llm]

# %%
import os
import warnings

os.environ["TOKENIZERS_PARALLELISM"] = "false"
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

# %% [markdown]
# ### **Task 1**

# %% [markdown]
# Training a T5-base model for feature extraction.
#
# The model will be able to recognize the task intent (**task_1** or **task_2**) based on the given query. It can further extract the entities required for task 1 (**sample_name**, **exposure_time**, **angle**).
#
# Based on the task intent the program will run the corresponding task.
#
# For Task 1 deliverables, I provide the code and results of **Feature-extractor model** _*training*_, _*evaluation*_, and _*inference*_.

# %%
""" 
MODEL TRAINING:

You can check the training code from the file. For your reference, the hyper-params for fine-tuning model are given below:

model_name_or_path='t5-small',
tokenizer_name_or_path='t5-small',
max_seq_length=40,
learning_rate=3e-4,
weight_decay=0.0,
adam_epsilon=1e-8,
warmup_steps=0,
train_batch_size=1,
eval_batch_size=1,
num_train_epochs=60,
gradient_accumulation_steps=16,
n_gpu=1,
early_stop_callback=False,
fp_16=True,
opt_level='O1',
max_grad_norm=1,
seed=42,
"""

# %cd TaskRecognition/model
# !python train_ner.py
# %cd ../../
# Out:
# /data/Muzamil/projects/my_project/bnl_task/TaskRecognition/model
# [nltk_data] Downloading package punkt to /home/w02/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 50
# can we measure this sample</s></s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# task_no: task_1</s></s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# the exposure time for this experiment is set at 8 seconds.</s></s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# task_no: task_1; exposure_time: 8</s></s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# Using 16bit native Automatic Mixed Precision (AMP)
# /home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:147: LightningDeprecationWarning: Setting `Trainer(checkpoint_callback=<pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f716ef1aca0>)` is deprecated in v1.5 and will be removed in v1.7. Please consider using `Trainer(enable_checkpointing=<pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f716ef1aca0>)`.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/pytorch_lightning/trainer/configuration_validator.py:106: UserWarning: When using `Trainer(accumulate_grad_batches != 1)` and overriding `LightningModule.optimizer_{step,zero_grad}`, the hooks will not be called on every batch (rather, they are called on every optimization step).
#   rank_zero_warn(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#
#   | Name  | Type                       | Params
# -----------------------------------------------------
# 0 | model | T5ForConditionalGeneration | 60.5 M
# -----------------------------------------------------
# 60.5 M    Trainable params
# 0         Non-trainable params
# 60.5 M    Total params
# 121.013   Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/pytorch_lightning/trainer/data_loading.py:132: UserWarning: The dataloader, val_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 64 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# /home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/pytorch_lightning/trainer/data_loading.py:132: UserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 64 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Epoch 0:   0%|                                           | 0/53 [00:00<?, ?it/s]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/pytorch_lightning/loops/optimization/closure.py:35: LightningDeprecationWarning: One of the returned values {'log'} has a `grad_fn`. We will detach it automatically but this behaviour will change in v1.6. Please detach it manually: `return {'loss': ..., 'something': something.detach()}`
#   rank_zero_deprecation(
# Epoch 0:  28%|███▉          | 15/53 [00:01<00:02, 14.64it/s, loss=5.52, v_num=0]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/torch/optim/lr_scheduler.py:138: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# Epoch 0:  94%|█████████████▏| 50/53 [00:03<00:00, 16.13it/s, loss=5.38, v_num=0]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/3 [00:00<?, ?it/s]
# Epoch 0: 100%|██████████████| 53/53 [00:03<00:00, 15.88it/s, loss=5.38, v_num=0]
# Epoch 1:  96%|██████████████▍| 51/53 [00:03<00:00, 15.56it/s, loss=3.4, v_num=0]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/3 [00:00<?, ?it/s]
# Validating:  33%|███████████                      | 1/3 [00:00<00:00,  6.94it/s]
# Epoch 1: 100%|███████████████| 53/53 [00:03<00:00, 15.03it/s, loss=3.4, v_num=0]
# Epoch 2:  96%|█████████████▍| 51/53 [00:03<00:00, 15.68it/s, loss=1.92, v_num=0]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/3 [00:00<?, ?it/s]
# Validating:  33%|███████████                      | 1/3 [00:00<00:00,  7.41it/s]
# Epoch 2: 100%|██████████████| 53/53 [00:03<00:00, 15.15it/s, loss=1.92, v_num=0]
# Epoch 3:  96%|█████████████▍| 51/53 [00:03<00:00, 16.42it/s, loss=1.27, v_num=0]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/3 [00:00<?, ?it/s]
# Validating:  33%|███████████                      | 1/3 [00:00<00:00,  5.99it/s]
# Epoch 3: 100%|██████████████| 53/53 [00:03<00:00, 15.66it/s, loss=1.27, v_num=0]
# Epoch 4:  96%|████████████▌| 51/53 [00:03<00:00, 16.36it/s, loss=0.735, v_num=0]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/3 [00:00<?, ?it/s]
# Validating:  33%|███████████                      | 1/3 [00:00<00:00,  7.27it/s]
# Epoch 4: 100%|█████████████| 53/53 [00:03<00:00, 15.77it/s, loss=0.735, v_num=0]
# Epoch 5:  96%|████████████▌| 51/53 [00:03<00:00, 16.92it/s, loss=0.538, v_num=0]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/3 [00:00<?, ?it/s]
# Epoch 5: 100%|█████████████| 53/53 [00:03<00:00, 16.22it/s, loss=0.538, v_num=0]
# Epoch 6:  96%|████████████▌| 51/53 [00:02<00:00, 18.92it/s, loss=0.251, v_num=0]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/3 [00:00<?, ?it/s]
# Validating:  33%|███████████                      | 1/3 [00:00<00:00,  7.23it/s]
# Epoch 6: 100%|█████████████| 53/53 [00:02<00:00, 18.00it/s, loss=0.251, v_num=0]
# Epoch 7:  96%|████████████▌| 51/53 [00:02<00:00, 19.03it/s, loss=0.272, v_num=0]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/3 [00:00<?, ?it/s]
# Validating:  33%|███████████                      | 1/3 [00:00<00:00,  6.10it/s]
# Epoch 7: 100%|█████████████| 53/53 [00:02<00:00, 17.93it/s, loss=0.272, v_num=0]
# Epoch 8:  96%|████████████▌| 51/53 [00:02<00:00, 17.79it/s, loss=0.226, v_num=0]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/3 [00:00<?, ?it/s]
# Validating:  33%|███████████                      | 1/3 [00:00<00:00,  7.23it/s]
# Epoch 8: 100%|█████████████| 53/53 [00:03<00:00, 17.01it/s, loss=0.226, v_num=0]
# Epoch 9:  96%|████████████▌| 51/53 [00:02<00:00, 17.33it/s, loss=0.122, v_num=0]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/3 [00:00<?, ?it/s]
# Validating:  33%|███████████                      | 1/3 [00:00<00:00,  7.48it/s]
# Epoch 9: 100%|█████████████| 53/53 [00:03<00:00, 16.68it/s, loss=0.122, v_num=0]
# Epoch 10:  96%|███████████▌| 51/53 [00:02<00:00, 18.23it/s, loss=0.113, v_num=0]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/3 [00:00<?, ?it/s]
# Epoch 10: 100%|████████████| 53/53 [00:03<00:00, 17.50it/s, loss=0.113, v_num=0]
# Epoch 11:  96%|████████████▌| 51/53 [00:03<00:00, 16.56it/s, loss=0.11, v_num=0]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/3 [00:00<?, ?it/s]
# Epoch 11: 100%|█████████████| 53/53 [00:03<00:00, 15.98it/s, loss=0.11, v_num=0]
# Epoch 12:  96%|██████████▌| 51/53 [00:02<00:00, 17.34it/s, loss=0.0809, v_num=0]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/3 [00:00<?, ?it/s]
# Epoch
v_num=0]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/3 [00:00<?, ?it/s]
# Validating:  33%|███████████                      | 1/3 [00:00<00:00,  6.03it/s]
# Epoch 58: 100%|██████████| 53/53 [00:02<00:00, 18.32it/s, loss=0.00951, v_num=0]
# Epoch 59:  96%|█████████▌| 51/53 [00:02<00:00, 19.20it/s, loss=0.00537, v_num=0]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/3 [00:00<?, ?it/s]
# Validating:  33%|███████████                      | 1/3 [00:00<00:00,  6.42it/s]
# Epoch 59: 100%|██████████| 53/53 [00:02<00:00, 18.17it/s, loss=0.00537, v_num=0]
# Epoch 59: 100%|██████████| 53/53 [00:04<00:00, 12.65it/s, loss=0.00537, v_num=0]
# /data/Muzamil/projects/my_project/bnl_task

# %%
# MODEL EVALUATION:

# %cd TaskRecognition/model
# !python evaluate_ner.py
# %cd ../../
# Out:
# /data/Muzamil/projects/my_project/bnl_task/TaskRecognition/model
# 50
# can we measure this sample</s></s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# task_no: task_1</s></s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#   0%|                                                    | 0/50 [00:00<?, ?it/s]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# /data/Muzamil/projects/my_project/bnl_task/TaskRecognition/model/evaluate_ner.py:95: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   metric = load_metric("seqeval")
# Text:  can we measure this sample
# Predictions:  task_no: task_1
# Targets:  task_no: task_1
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'O']
# True Token Class:  ['O', 'O', 'O', 'O', 'O']
# =====================================================================
#
# /home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/numpy/lib/function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# /home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# {'overall_precision': 0.0, 'overall_recall': 0.0, 'overall_f1': 0.0, 'overall_accuracy': 1.0}
#   2%|▉                                           | 1/50 [00:02<02:18,  2.82s/it]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  could we perform measurements on this particular sample ?
# Predictions:  task_no: task_1
# Targets:  task_no: task_1
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# True Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# =====================================================================
#
# /home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/numpy/lib/function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# /home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# {'overall_precision': 0.0, 'overall_recall': 0.0, 'overall_f1': 0.0, 'overall_accuracy': 1.0}
#   4%|█▊                                          | 2/50 [00:03<01:22,  1.72s/it]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  is it possible to assess this particular specimen ?
# Predictions:  task_no: task_1
# Targets:  task_no: task_1
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# True Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# =====================================================================
#
# /home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/numpy/lib/function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# /home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# {'overall_precision': 0.0, 'overall_recall': 0.0, 'overall_f1': 0.0, 'overall_accuracy': 1.0}
#   6%|██▋                                         | 3/50 [00:04<01:03,  1.35s/it]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  assuming q is 1 and the wavelength  is 1 , what angle  in degrees corresponds to the scattering event ? additionally , what is the interplanar
# Predictions:  task_no: task_2
# Targets:  task_no: task_2
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# True Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# =====================================================================
#
# /home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/numpy/lib/function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# /home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# {'overall_precision': 0.0, 'overall_recall': 0.0, 'overall_f1': 0.0, 'overall_accuracy': 1.0}
#   8%|███▌                                        | 4/50 [00:05<00:54,  1.19s/it]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  explore this perovskite sample , adjusting the incident angle to 0.5 degree .
# Predictions:  task_no: task_1; sample_name: perovskite;
# Targets:  task_no: task_1; sample_name: perovskite; angle: 0.5
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# True Token Class:  ['O', 'O', 'B-SAMPLE_NAME', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ANGLE', 'O', 'O']
# =====================================================================
#
# /home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'ANGLE': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 1}, 'SAMPLE_NAME': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 1}, 'overall_precision': 0.0, 'overall_recall': 0.0, 'overall_f1': 0.0, 'overall_accuracy': 0.96875}
#  10%|████▍                                       | 5/50 [00:06<00:50,  1.13s/it]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  the exposure time for this experiment is set at 8 seconds .
# Predictions:  task_no: task_1; exposure_time: 8
# Targets:  task_no: task_1; exposure_time: 8
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EXPOSURE_TIME', 'O', 'O']
# True Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EXPOSURE_TIME', 'O', 'O']
# =====================================================================
#
# /home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'ANGLE': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 1}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 1}, 'SAMPLE_NAME': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 1}, 'overall_precision': 1.0, 'overall_recall': 0.3333333333333333, 'overall_f1': 0.5, 'overall_accuracy': 0.9736842105263158}
#  12%|█████▎                                      | 6/50 [00:07<00:48,  1.09s/it]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  if a material exhibits a spacing between crystal lattice planes d of 6 , what does this correspond to in terms of the reciprocal/fourier space
# Predictions:  task_no: task_2
# Targets:  task_no: task_2
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# True Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# =====================================================================
#
# /home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'ANGLE': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 1}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 1}, 'SAMPLE_NAME': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 1}, 'overall_precision': 1.0, 'overall_recall': 0.3333333333333333, 'overall_f1': 0.5, 'overall_accuracy': 0.9801980198019802}
#  14%|██████▏                                     | 7/50 [00:08<00:44,  1.04s/it]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  if there is a peak in the reciprocal space scattering vector q at 1 , what is the corresponding interplanar spacing d ?
# Predictions:  task_no: task_2
# Targets:  task_no: task_2
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# True Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# =====================================================================
#
# /home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'ANGLE': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 1}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 1}, 'SAMPLE_NAME': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 1}, 'overall_precision': 1.0, 'overall_recall': 0.3333333333333333, 'overall_f1': 0.5, 'overall_accuracy': 0.9838709677419355}
#  16%|███████                                     | 8/50 [00:09<00:42,  1.00s/it]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  given that q is 1 and the wavelength  is 1 , what is the scattering angle  in degrees ? additionally , what is the interplanar spacing d
# Predictions:  task_no: task_2
# Targets:  task_no: task_2
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# True Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# =====================================================================
#
# /home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'ANGLE': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 1}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'number': 1}, 'SAMPLE_NAME': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 1}, 'overall_precision': 1.0, 'overall_recall': 0.3333333333333333, 'overall_f1': 0.5, 'overall_accuracy': 0.9869281045751634}
#  18%|███████▉                                    | 9/50 [00:10<00:40,  1.02it/s]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  collect data for this material . let us do an exposure time of 10 seconds and incident angles at 0.1 and 0.2 degree
# Predictions:  task_no: task_1; angle: 0.1; angle: 0.2;
# Targets:  task_no: task_1; angle: 0.1; angle: 0.2; exposure_time: 10
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ANGLE', 'O', 'O', 'O']
# True Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EXPOSURE_TIME', 'O', 'O', 'O', 'O', 'O', 'B-ANGLE', 'O', 'B-ANGLE', 'O']
# =====================================================================
#
# /home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'ANGLE': {'precision': 1.0, 'recall': 0.3333333333333333, 'f1': 0.5, 'number': 3}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 0.5, 'f1': 0.6666666666666666, 'number': 2}, 'SAMPLE_NAME': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 1}, 'overall_precision': 1.0, 'overall_recall': 0.3333333333333333, 'overall_f1': 0.5, 'overall_accuracy': 0.9772727272727273}
#  20%|████████▌                                  | 10/50 [00:11<00:39,  1.02it/s]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  the theta for this experiment is set at 0.4 .
# Predictions:  task_no: task_1; angle: 0.4
# Targets:  task_no: task_1; angle: 0.4
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ANGLE', 'O']
# True Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ANGLE', 'O']
# =====================================================================
#
# /home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'ANGLE': {'precision': 1.0, 'recall': 0.5, 'f1': 0.6666666666666666, 'number': 4}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 0.5, 'f1': 0.6666666666666666, 'number': 2}, 'SAMPLE_NAME': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 1}, 'overall_precision': 1.0, 'overall_recall': 0.42857142857142855, 'overall_f1': 0.6, 'overall_accuracy': 0.978494623655914}
#  22%|█████████▍                                 | 11/50 [00:12<00:38,  1.02it/s]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  the exposure time will be 0.1 degree for 8 seconds .
# Predictions:  task_no: task_1; angle: 0.1; exposure_time: 8
# Targets:  task_no: task_1; angle: 0.1; exposure_time: 8
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'O', 'B-ANGLE', 'O', 'O', 'B-EXPOSURE_TIME', 'O', 'O']
# True Token Class:  ['O', 'O', 'O', 'O', 'O', 'B-ANGLE', 'O', 'O', 'B-EXPOSURE_TIME', 'O', 'O']
# =====================================================================
#
# /home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'ANGLE': {'precision': 1.0, 'recall': 0.6, 'f1': 0.7499999999999999, 'number': 5}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 0.6666666666666666, 'f1': 0.8, 'number': 3}, 'SAMPLE_NAME': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 1}, 'overall_precision': 1.0, 'overall_recall': 0.5555555555555556, 'overall_f1': 0.7142857142857143, 'overall_accuracy': 0.9796954314720813}
#  24%|██████████▎                                | 12/50 [00:13<00:37,  1.01it/s]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  we 're planning to measure this polymer sample with an incident angle of 0.3 .
# Predictions:  task_no: task_1; angle: 0.3; sample_name: poly
# Targets:  task_no: task_1; angle: 0.3; sample_name: polymer
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ANGLE', 'O']
# True Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'B-SAMPLE_NAME', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ANGLE', 'O']
# =====================================================================
#
# /home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'ANGLE': {'precision': 1.0, 'recall': 0.6666666666666666, 'f1': 0.8, 'number': 6}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 0.6666666666666666, 'f1': 0.8, 'number': 3}, 'SAMPLE_NAME': {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'number': 2}, 'overall_precision': 1.0, 'overall_recall': 0.5454545454545454, 'overall_f1': 0.7058823529411764, 'overall_accuracy': 0.9764150943396226}
#  26%|███████████▏                               | 13/50 [00:14<00:37,  1.00s/it]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  let 's obtain data for the perovskite material .
# Predictions:  task_no: task_1; sample_name: perovskite
# Targets:  task_no: task_1; sample_name: perovskite
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'B-SAMPLE_NAME', 'O', 'O']
# True Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'B-SAMPLE_NAME', 'O', 'O']
# =====================================================================
#
# {'ANGLE': {'precision': 1.0, 'recall': 0.6666666666666666, 'f1': 0.8, 'number': 6}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 0.6666666666666666, 'f1': 0.8, 'number': 3}, 'SAMPLE_NAME': {'precision': 1.0, 'recall': 0.3333333333333333, 'f1': 0.5, 'number': 3}, 'overall_precision': 1.0, 'overall_recall': 0.5833333333333334, 'overall_f1': 0.7368421052631579, 'overall_accuracy': 0.9773755656108597}
#  28%|████████████                               | 14/50 [00:15<00:36,  1.01s/it]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  let 's measure this perovskite sample
# Predictions:  task_no: task_1; sample_name: perovskite
# Targets:  task_no: task_1; sample_name: perovskite
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'B-SAMPLE_NAME', 'O']
# True Token Class:  ['O', 'O', 'O', 'O', 'B-SAMPLE_NAME', 'O']
# =====================================================================
#
# {'ANGLE': {'precision': 1.0, 'recall': 0.6666666666666666, 'f1': 0.8, 'number': 6}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 0.6666666666666666, 'f1': 0.8, 'number': 3}, 'SAMPLE_NAME': {'precision': 1.0, 'recall': 0.5, 'f1': 0.6666666666666666, 'number': 4}, 'overall_precision': 1.0, 'overall_recall': 0.6153846153846154, 'overall_f1': 0.761904761904762, 'overall_accuracy': 0.9779735682819384}
#  30%|████████████▉                              | 15/50 [00:16<00:35,  1.01s/it]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  i want to measure a polymer sample
# Predictions:  task_no: task_1; sample_name: polymer
# Targets:  task_no: task_1; sample_name: polymer
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'O', 'B-SAMPLE_NAME', 'O']
# True Token Class:  ['O', 'O', 'O', 'O', 'O', 'B-SAMPLE_NAME', 'O']
# =====================================================================
#
# {'ANGLE': {'precision': 1.0, 'recall': 0.6666666666666666, 'f1': 0.8, 'number': 6}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 0.6666666666666666, 'f1': 0.8, 'number': 3}, 'SAMPLE_NAME': {'precision': 1.0, 'recall': 0.6, 'f1': 0.7499999999999999, 'number': 5}, 'overall_precision': 1.0, 'overall_recall': 0.6428571428571429, 'overall_f1': 0.782608695652174, 'overall_accuracy': 0.9786324786324786}
#  32%|█████████████▊                             | 16/50 [00:17<00:34,  1.01s/it]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  we want to look at this sample to understand its structure
# Predictions:  task_no: task_1
# Targets:  task_no: task_1
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# True Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# =====================================================================
#
# {'ANGLE': {'precision': 1.0, 'recall': 0.6666666666666666, 'f1': 0.8, 'number': 6}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 0.6666666666666666, 'f1': 0.8, 'number': 3}, 'SAMPLE_NAME': {'precision': 1.0, 'recall': 0.6, 'f1': 0.7499999999999999, 'number': 5}, 'overall_precision': 1.0, 'overall_recall': 0.6428571428571429, 'overall_f1': 0.782608695652174, 'overall_accuracy': 0.9795918367346939}
#  34%|██████████████▌                            | 17/50 [00:18<00:32,  1.01it/s]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  collect data for this material , exposing it for 10 seconds with incident angles at 0.1 and 0.2 degrees .
# Predictions:  task_no: task_1; angle: 0.1; angle: 0.2;
# Targets:  task_no: task_1; angle: 0.1; angle: 0.2; exposure_time: 10
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ANGLE', 'O', 'O', 'O', 'O']
# True Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EXPOSURE_TIME', 'O', 'O', 'O', 'O', 'O', 'B-ANGLE', 'O', 'B-ANGLE', 'O', 'O']
# =====================================================================
#
# {'ANGLE': {'precision': 1.0, 'recall': 0.625, 'f1': 0.7692307692307693, 'number': 8}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 0.5, 'f1': 0.6666666666666666, 'number': 4}, 'SAMPLE_NAME': {'precision': 1.0, 'recall': 0.6, 'f1': 0.7499999999999999, 'number': 5}, 'overall_precision': 1.0, 'overall_recall': 0.5882352941176471, 'overall_f1': 0.7407407407407407, 'overall_accuracy': 0.9735849056603774}
#  36%|███████████████▍                           | 18/50 [00:19<00:31,  1.02it/s]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  we are considering a duration of two seconds for the exposure .
# Predictions:  task_no: task_1; exposure_time: two
# Targets:  task_no: task_1; exposure_time: two
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'B-EXPOSURE_TIME', 'O', 'O', 'O', 'O', 'O']
# True Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'B-EXPOSURE_TIME', 'O', 'O', 'O', 'O', 'O']
# =====================================================================
#
# {'ANGLE': {'precision': 1.0, 'recall': 0.625, 'f1': 0.7692307692307693, 'number': 8}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 0.6, 'f1': 0.7499999999999999, 'number': 5}, 'SAMPLE_NAME': {'precision': 1.0, 'recall': 0.6, 'f1': 0.7499999999999999, 'number': 5}, 'overall_precision': 1.0, 'overall_recall': 0.6111111111111112, 'overall_f1': 0.7586206896551725, 'overall_accuracy': 0.9747292418772563}
#  38%|████████████████▎                          | 19/50 [00:20<00:30,  1.01it/s]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  we 're interested in examining this sample to gain insights into its structure .
# Predictions:  task_no: task_1
# Targets:  task_no: task_1
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# True Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# =====================================================================
#
# {'ANGLE': {'precision': 1.0, 'recall': 0.625, 'f1': 0.7692307692307693, 'number': 8}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 0.6, 'f1': 0.7499999999999999, 'number': 5}, 'SAMPLE_NAME': {'precision': 1.0, 'recall': 0.6, 'f1': 0.7499999999999999, 'number': 5}, 'overall_precision': 1.0, 'overall_recall': 0.6111111111111112, 'overall_f1': 0.7586206896551725, 'overall_accuracy': 0.9759450171821306}
#  40%|█████████████████▏                         | 20/50 [00:21<00:29,  1.03it/s]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  the incident angle for this experiment is 0.5 degree .
# Predictions:  task_no: task_1; angle: 0.5
# Targets:  task_no: task_1; angle: 0.5
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ANGLE', 'O', 'O']
# True Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ANGLE', 'O', 'O']
# =====================================================================
#
# {'ANGLE': {'precision': 1.0, 'recall': 0.6666666666666666, 'f1': 0.8, 'number': 9}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 0.6, 'f1': 0.7499999999999999, 'number': 5}, 'SAMPLE_NAME': {'precision': 1.0, 'recall': 0.6, 'f1': 0.7499999999999999, 'number': 5}, 'overall_precision': 1.0, 'overall_recall': 0.631578947368421, 'overall_f1': 0.7741935483870968, 'overall_accuracy': 0.9767441860465116}
#  42%|██████████████████                         | 21/50 [00:22<00:28,  1.03it/s]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  exposure time of 8 seconds
# Predictions:  task_no: task_1; exposure_time: 8
# Targets:  task_no: task_1; exposure_time: 8
# Predicted Token Class:  ['O', 'O', 'O', 'B-EXPOSURE_TIME', 'O']
# True Token Class:  ['O', 'O', 'O', 'B-EXPOSURE_TIME', 'O']
# =====================================================================
#
# {'ANGLE': {'precision': 1.0, 'recall': 0.6666666666666666, 'f1': 0.8, 'number': 9}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 0.6666666666666666, 'f1': 0.8, 'number': 6}, 'SAMPLE_NAME': {'precision': 1.0, 'recall': 0.6, 'f1': 0.7499999999999999, 'number': 5}, 'overall_precision': 1.0, 'overall_recall': 0.65, 'overall_f1': 0.787878787878788, 'overall_accuracy': 0.9771241830065359}
#  44%|██████████████████▉                        | 22/50 [00:23<00:27,  1.03it/s]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  let 's explore the effects with a time span of 0.5 seconds .
# Predictions:  task_no: task_1; exposure_time: 0.5
# Targets:  task_no: task_1; exposure_time: 0.5
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EXPOSURE_TIME', 'O', 'O']
# True Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EXPOSURE_TIME', 'O', 'O']
# =====================================================================
#
# {'ANGLE': {'precision': 1.0, 'recall': 0.6666666666666666, 'f1': 0.8, 'number': 9}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 0.7142857142857143, 'f1': 0.8333333333333333, 'number': 7}, 'SAMPLE_NAME': {'precision': 1.0, 'recall': 0.6, 'f1': 0.7499999999999999, 'number': 5}, 'overall_precision': 1.0, 'overall_recall': 0.6666666666666666, 'overall_f1': 0.8, 'overall_accuracy': 0.9780564263322884}
#  46%|███████████████████▊                       | 23/50 [00:24<00:26,  1.02it/s]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  i 'd like to conduct measurements on this sample .
# Predictions:  task_no: task_1
# Targets:  task_no: task_1
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# True Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# =====================================================================
#
# {'ANGLE': {'precision': 1.0, 'recall': 0.6666666666666666, 'f1': 0.8, 'number': 9}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 0.7142857142857143, 'f1': 0.8333333333333333, 'number': 7}, 'SAMPLE_NAME': {'precision': 1.0, 'recall': 0.6, 'f1': 0.7499999999999999, 'number': 5}, 'overall_precision': 1.0, 'overall_recall': 0.6666666666666666, 'overall_f1': 0.8, 'overall_accuracy': 0.9787234042553191}
#  48%|████████████████████▋                      | 24/50 [00:25<00:25,  1.02it/s]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  is it feasible to measure this material ?
# Predictions:  task_no: task_1
# Targets:  task_no: task_1
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# True Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# =====================================================================
#
# {'ANGLE': {'precision': 1.0, 'recall': 0.6666666666666666, 'f1': 0.8, 'number': 9}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 0.7142857142857143, 'f1': 0.8333333333333333, 'number': 7}, 'SAMPLE_NAME': {'precision': 1.0, 'recall': 0.6, 'f1': 0.7499999999999999, 'number': 5}, 'overall_precision': 1.0, 'overall_recall': 0.6666666666666666, 'overall_f1': 0.8, 'overall_accuracy': 0.9792284866468842}
#  50%|█████████████████████▌                     | 25/50 [00:26<00:24,  1.03it/s]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  for structure with d spacing of 6 , what is the corresponding q in the reciprocal/fourier space ?
# Predictions:  task_no: task_2
# Targets:  task_no: task_2
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# True Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# =====================================================================
#
# {'ANGLE': {'precision': 1.0, 'recall': 0.6666666666666666, 'f1': 0.8, 'number': 9}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 0.7142857142857143, 'f1': 0.8333333333333333, 'number': 7}, 'SAMPLE_NAME': {'precision': 1.0, 'recall': 0.6, 'f1': 0.7499999999999999, 'number': 5}, 'overall_precision': 1.0, 'overall_recall': 0.6666666666666666, 'overall_f1': 0.8, 'overall_accuracy': 0.9802816901408451}
#  52%|██████████████████████▎                    | 26/50 [00:27<00:22,  1.05it/s]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  theta of 0.4
# Predictions:  task_no: task_1; angle: 0.4
# Targets:  task_no: task_1; angle: 0.4
# Predicted Token Class:  ['O', 'O', 'B-ANGLE']
# True Token Class:  ['O', 'O', 'B-ANGLE']
# =====================================================================
#
# {'ANGLE': {'precision': 1.0, 'recall': 0.7, 'f1': 0.8235294117647058, 'number': 10}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 0.7142857142857143, 'f1': 0.8333333333333333, 'number': 7}, 'SAMPLE_NAME': {'precision': 1.0, 'recall': 0.6, 'f1': 0.7499999999999999, 'number': 5}, 'overall_precision': 1.0, 'overall_recall': 0.6818181818181818, 'overall_f1': 0.8108108108108109, 'overall_accuracy': 0.9804469273743017}
#  54%|███████████████████████▏                   | 27/50 [00:28<00:22,  1.04it/s]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  when we have q peak of 1 , what is the d spacing ?
# Predictions:  task_no: task_2
# Targets:  task_no: task_2
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# True Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# =====================================================================
#
# {'ANGLE': {'precision': 1.0, 'recall': 0.7, 'f1': 0.8235294117647058, 'number': 10}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 0.7142857142857143, 'f1': 0.8333333333333333, 'number': 7}, 'SAMPLE_NAME': {'precision': 1.0, 'recall': 0.6, 'f1': 0.7499999999999999, 'number': 5}, 'overall_precision': 1.0, 'overall_recall': 0.6818181818181818, 'overall_f1': 0.8108108108108109, 'overall_accuracy': 0.9811827956989247}
#  56%|████████████████████████                   | 28/50 [00:29<00:21,  1.04it/s]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  let 's investigate this sample for 0.5 degree exposure for 0.3 seconds .
# Predictions:  task_no: task_1; angle: 0.5; exposure_time:
# Targets:  task_no: task_1; angle: 0.5; exposure_time: 0.3
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'B-ANGLE', 'O', 'O', 'O', 'O', 'O', 'O']
# True Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'B-ANGLE', 'O', 'O', 'O', 'B-EXPOSURE_TIME', 'O', 'O']
# =====================================================================
#
# {'ANGLE': {'precision': 1.0, 'recall': 0.7272727272727273, 'f1': 0.8421052631578948, 'number': 11}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 0.625, 'f1': 0.7692307692307693, 'number': 8}, 'SAMPLE_NAME': {'precision': 1.0, 'recall': 0.6, 'f1': 0.7499999999999999, 'number': 5}, 'overall_precision': 1.0, 'overall_recall': 0.6666666666666666, 'overall_f1': 0.8, 'overall_accuracy': 0.9792207792207792}
#  58%|████████████████████████▉                  | 29/50 [00:30<00:20,  1.02it/s]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  0.1 degree
# Predictions:  task_no: task_1; angle: 0.1
# Targets:  task_no: task_1; angle: 0.1
# Predicted Token Class:  ['B-ANGLE', 'O']
# True Token Class:  ['B-ANGLE', 'O']
# =====================================================================
#
# {'ANGLE': {'precision': 1.0, 'recall': 0.75, 'f1': 0.8571428571428571, 'number': 12}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 0.625, 'f1': 0.7692307692307693, 'number': 8}, 'SAMPLE_NAME': {'precision': 1.0, 'recall': 0.6, 'f1': 0.7499999999999999, 'number': 5}, 'overall_precision': 1.0, 'overall_recall': 0.68, 'overall_f1': 0.8095238095238095, 'overall_accuracy': 0.979328165374677}
#  60%|█████████████████████████▊                 | 30/50 [00:31<00:19,  1.01it/s]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  collect data for perovskite material
# Predictions:  task_no: task_1; sample_name: perovskite
# Targets:  task_no: task_1; sample_name: perovskite
# Predicted Token Class:  ['O', 'O', 'O', 'B-SAMPLE_NAME', 'O']
# True Token Class:  ['O', 'O', 'O', 'B-SAMPLE_NAME', 'O']
# =====================================================================
#
# {'ANGLE': {'precision': 1.0, 'recall': 0.75, 'f1': 0.8571428571428571, 'number': 12}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 0.625, 'f1': 0.7692307692307693, 'number': 8}, 'SAMPLE_NAME': {'precision': 1.0, 'recall': 0.6666666666666666, 'f1': 0.8, 'number': 6}, 'overall_precision': 1.0, 'overall_recall': 0.6923076923076923, 'overall_f1': 0.8181818181818181, 'overall_accuracy': 0.9795918367346939}
#  62%|██████████████████████████▋                | 31/50 [00:32<00:18,  1.02it/s]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  for a structure with an interplanar spacing d of 6 , what value does the reciprocal/fourier space scattering vector q correspond to ?
# Predictions:  task_no: task_2
# Targets:  task_no: task_2
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# True Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# =====================================================================
#
# {'ANGLE': {'precision': 1.0, 'recall': 0.75, 'f1': 0.8571428571428571, 'number': 12}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 0.625, 'f1': 0.7692307692307693, 'number': 8}, 'SAMPLE_NAME': {'precision': 1.0, 'recall': 0.6666666666666666, 'f1': 0.8, 'number': 6}, 'overall_precision': 1.0, 'overall_recall': 0.6923076923076923, 'overall_f1': 0.8181818181818181, 'overall_accuracy': 0.980722891566265}
#  64%|███████████████████████████▌               | 32/50 [00:32<00:17,  1.04it/s]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  for this polymer sample , i propose a measurement period of ten seconds .
# Predictions:  task_no: task_1; exposure_time: ten; sample_name
# Targets:  task_no: task_1; exposure_time: ten; sample_name: polymer
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EXPOSURE_TIME', 'O', 'O']
# True Token Class:  ['O', 'O', 'B-SAMPLE_NAME', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EXPOSURE_TIME', 'O', 'O']
# =====================================================================
#
# {'ANGLE': {'precision': 1.0, 'recall': 0.75, 'f1': 0.8571428571428571, 'number': 12}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 0.6666666666666666, 'f1': 0.8, 'number': 9}, 'SAMPLE_NAME': {'precision': 1.0, 'recall': 0.5714285714285714, 'f1': 0.7272727272727273, 'number': 7}, 'overall_precision': 1.0, 'overall_recall': 0.6785714285714286, 'overall_f1': 0.8085106382978724, 'overall_accuracy': 0.9790209790209791}
#  66%|████████████████████████████▍              | 33/50 [00:34<00:16,  1.01it/s]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  time 0.5 seconds
# Predictions:  task_no: task_1; exposure_time: 0.5
# Targets:  task_no: task_1; exposure_time: 0.5
# Predicted Token Class:  ['O', 'B-EXPOSURE_TIME', 'O']
# True Token Class:  ['O', 'B-EXPOSURE_TIME', 'O']
# =====================================================================
#
# {'ANGLE': {'precision': 1.0, 'recall': 0.75, 'f1': 0.8571428571428571, 'number': 12}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 0.7, 'f1': 0.8235294117647058, 'number': 10}, 'SAMPLE_NAME': {'precision': 1.0, 'recall': 0.5714285714285714, 'f1': 0.7272727272727273, 'number': 7}, 'overall_precision': 1.0, 'overall_recall': 0.6896551724137931, 'overall_f1': 0.8163265306122449, 'overall_accuracy': 0.9791666666666666}
#  68%|█████████████████████████████▏             | 34/50 [00:35<00:15,  1.00it/s]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  if q is 1 , and the wavelength lambda  is 1 , what is the scattering angle  in degree ? what is the d spacing
# Predictions:  task_no: task_2
# Targets:  task_no: task_2
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# True Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# =====================================================================
#
# ...
#  76%|████████████████████████████████▋          | 38/50 [00:38<00:11,  1.02it/s]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  we want to look at this perovskite to understand its structure . we think 5 seconds of exposure should be sufficient . theta of 0.2 would be good .
# Predictions:  task_no: task_1; sample_name: perovskite;
# Targets:  task_no: task_1; sample_name: perovskite; exposure_time: 5; angle: 0.2
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# True Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'B-SAMPLE_NAME', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-EXPOSURE_TIME', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ANGLE', 'O', 'O', 'O', 'O']
# =====================================================================
#
# {'ANGLE': {'precision': 1.0, 'recall': 0.6923076923076923, 'f1': 0.8181818181818181, 'number': 13}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 0.6666666666666666, 'f1': 0.8, 'number': 12}, 'SAMPLE_NAME': {'precision': 1.0, 'recall': 0.5, 'f1': 0.6666666666666666, 'number': 8}, 'overall_precision': 1.0, 'overall_recall': 0.6363636363636364, 'overall_f1': 0.7777777777777778, 'overall_accuracy': 0.9761431411530815}
#  78%|█████████████████████████████████▌         | 39/50 [00:39<00:10,  1.02it/s]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  let 's vary the angle to 0.3 for this measurement .
# Predictions:  task_no: task_1; angle: 0.3
# Targets:  task_no: task_1; angle: 0.3
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'B-ANGLE', 'O', 'O', 'O', 'O']
# True Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'B-ANGLE', 'O', 'O', 'O', 'O']
# =====================================================================
#
# {'ANGLE': {'precision': 1.0, 'recall': 0.7142857142857143, 'f1': 0.8333333333333333, 'number': 14}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 0.6666666666666666, 'f1': 0.8, 'number': 12}, 'SAMPLE_NAME': {'precision': 1.0, 'recall': 0.5, 'f1': 0.6666666666666666, 'number': 8}, 'overall_precision': 1.0, 'overall_recall': 0.6470588235294118, 'overall_f1': 0.7857142857142858, 'overall_accuracy': 0.9766536964980544}
#  80%|██████████████████████████████████▍        | 40/50 [00:40<00:09,  1.02it/s]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  i want to measure this sample
# Predictions:  task_no: task_1
# Targets:  task_no: task_1
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'O', 'O']
# True Token Class:  ['O', 'O', 'O', 'O', 'O', 'O']
# =====================================================================
#
# {'ANGLE': {'precision': 1.0, 'recall': 0.7142857142857143, 'f1': 0.8333333333333333, 'number': 14}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 0.6666666666666666, 'f1': 0.8, 'number': 12}, 'SAMPLE_NAME': {'precision': 1.0, 'recall': 0.5, 'f1': 0.6666666666666666, 'number': 8}, 'overall_precision': 1.0, 'overall_recall': 0.6470588235294118, 'overall_f1': 0.7857142857142858, 'overall_accuracy': 0.9769230769230769}
#  82%|███████████████████████████████████▎       | 41/50 [00:41<00:08,  1.01it/s]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  i want to measure this polymer sample for ten seconds at an incident angle of 0.1 degree
# Predictions:  task_no: task_1; angle: 0.1; exposure_time:
# Targets:  task_no: task_1; angle: 0.1; exposure_time: ten; sample_name: polymer
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ANGLE', 'O']
# True Token Class:  ['O', 'O', 'O', 'O', 'O', 'B-SAMPLE_NAME', 'O', 'O', 'B-EXPOSURE_TIME', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ANGLE', 'O']
# =====================================================================
#
# {'ANGLE': {'precision': 1.0, 'recall': 0.7333333333333333, 'f1': 0.846153846153846, 'number': 15}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 0.6153846153846154, 'f1': 0.761904761904762, 'number': 13}, 'SAMPLE_NAME': {'precision': 1.0, 'recall': 0.4444444444444444, 'f1': 0.6153846153846153, 'number': 9}, 'overall_precision': 1.0, 'overall_recall': 0.6216216216216216, 'overall_f1': 0.7666666666666667, 'overall_accuracy': 0.9739292364990689}
#  84%|████████████████████████████████████       | 42/50 [00:42<00:08,  1.01s/it]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  angle 0.3
# Predictions:  task_no: task_1; angle: 0.3
# Targets:  task_no: task_1; angle: 0.3
# Predicted Token Class:  ['O', 'B-ANGLE']
# True Token Class:  ['O', 'B-ANGLE']
# =====================================================================
#
# {'ANGLE': {'precision': 1.0, 'recall': 0.75, 'f1': 0.8571428571428571, 'number': 16}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 0.6153846153846154, 'f1': 0.761904761904762, 'number': 13}, 'SAMPLE_NAME': {'precision': 1.0, 'recall': 0.4444444444444444, 'f1': 0.6153846153846153, 'number': 9}, 'overall_precision': 1.0, 'overall_recall': 0.631578947368421, 'overall_f1': 0.7741935483870968, 'overall_accuracy': 0.974025974025974}
#  86%|████████████████████████████████████▉      | 43/50 [00:43<00:07,  1.02s/it]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  when the reciprocal space scattering vector q peaks at 1 , what does this imply for the interplanar spacing d ?
# Predictions:  task_no: task_2
# Targets:  task_no: task_2
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# True Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# =====================================================================
#
# {'ANGLE': {'precision': 1.0, 'recall': 0.75, 'f1': 0.8571428571428571, 'number': 16}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 0.6153846153846154, 'f1': 0.761904761904762, 'number': 13}, 'SAMPLE_NAME': {'precision': 1.0, 'recall': 0.4444444444444444, 'f1': 0.6153846153846153, 'number': 9}, 'overall_precision': 1.0, 'overall_recall': 0.631578947368421, 'overall_f1': 0.7741935483870968, 'overall_accuracy': 0.975}
#  88%|█████████████████████████████████████▊     | 44/50 [00:44<00:06,  1.01s/it]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  collect data for this material
# Predictions:  task_no: task_1
# Targets:  task_no: task_1
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'O']
# True Token Class:  ['O', 'O', 'O', 'O', 'O']
# =====================================================================
#
# {'ANGLE': {'precision': 1.0, 'recall': 0.75, 'f1': 0.8571428571428571, 'number': 16}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 0.6153846153846154, 'f1': 0.761904761904762, 'number': 13}, 'SAMPLE_NAME': {'precision': 1.0, 'recall': 0.4444444444444444, 'f1': 0.6153846153846153, 'number': 9}, 'overall_precision': 1.0, 'overall_recall': 0.631578947368421, 'overall_f1': 0.7741935483870968, 'overall_accuracy': 0.9752212389380531}
#  90%|██████████████████████████████████████▋    | 45/50 [00:45<00:04,  1.01it/s]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  consider an incident angle of 0.1 degree for this analysis .
# Predictions:  task_no: task_1; angle: 0.1
# Targets:  task_no: task_1; angle: 0.1
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'O', 'B-ANGLE', 'O', 'O', 'O', 'O', 'O']
# True Token Class:  ['O', 'O', 'O', 'O', 'O', 'B-ANGLE', 'O', 'O', 'O', 'O', 'O']
# =====================================================================
#
# {'ANGLE': {'precision': 1.0, 'recall': 0.7647058823529411, 'f1': 0.8666666666666666, 'number': 17}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 0.6153846153846154, 'f1': 0.761904761904762, 'number': 13}, 'SAMPLE_NAME': {'precision': 1.0, 'recall': 0.4444444444444444, 'f1': 0.6153846153846153, 'number': 9}, 'overall_precision': 1.0, 'overall_recall': 0.6410256410256411, 'overall_f1': 0.7812500000000001, 'overall_accuracy': 0.9756944444444444}
#  92%|███████████████████████████████████████▌   | 46/50 [00:46<00:03,  1.01it/s]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  i suggest an exposure time of two seconds for this analysis .
# Predictions:  task_no: task_1; exposure_time: two
# Targets:  task_no: task_1; exposure_time: two
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'B-EXPOSURE_TIME', 'O', 'O', 'O', 'O', 'O']
# True Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'B-EXPOSURE_TIME', 'O', 'O', 'O', 'O', 'O']
# =====================================================================
#
# {'ANGLE': {'precision': 1.0, 'recall': 0.7647058823529411, 'f1': 0.8666666666666666, 'number': 17}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 0.6428571428571429, 'f1': 0.782608695652174, 'number': 14}, 'SAMPLE_NAME': {'precision': 1.0, 'recall': 0.4444444444444444, 'f1': 0.6153846153846153, 'number': 9}, 'overall_precision': 1.0, 'overall_recall': 0.65, 'overall_f1': 0.787878787878788, 'overall_accuracy': 0.9761904761904762}
#  94%|████████████████████████████████████████▍  | 47/50 [00:47<00:02,  1.01it/s]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  i want to measure polymer sample
# Predictions:  task_no: task_1; sample_name: polymer
# Targets:  task_no: task_1; sample_name: polymer
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'B-SAMPLE_NAME', 'O']
# True Token Class:  ['O', 'O', 'O', 'O', 'B-SAMPLE_NAME', 'O']
# =====================================================================
#
# {'ANGLE': {'precision': 1.0, 'recall': 0.7647058823529411, 'f1': 0.8666666666666666, 'number': 17}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 0.6428571428571429, 'f1': 0.782608695652174, 'number': 14}, 'SAMPLE_NAME': {'precision': 1.0, 'recall': 0.5, 'f1': 0.6666666666666666, 'number': 10}, 'overall_precision': 1.0, 'overall_recall': 0.6585365853658537, 'overall_f1': 0.7941176470588235, 'overall_accuracy': 0.9764309764309764}
#  96%|█████████████████████████████████████████▎ | 48/50 [00:48<00:01,  1.00it/s]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  incident angle of 0.5 degree
# Predictions:  task_no: task_1; angle: 0.5
# Targets:  task_no: task_1; angle: 0.5
# Predicted Token Class:  ['O', 'O', 'O', 'B-ANGLE', 'O']
# True Token Class:  ['O', 'O', 'O', 'B-ANGLE', 'O']
# =====================================================================
#
# {'ANGLE': {'precision': 1.0, 'recall': 0.7777777777777778, 'f1': 0.8750000000000001, 'number': 18}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 0.6428571428571429, 'f1': 0.782608695652174, 'number': 14}, 'SAMPLE_NAME': {'precision': 1.0, 'recall': 0.5, 'f1': 0.6666666666666666, 'number': 10}, 'overall_precision': 1.0, 'overall_recall': 0.6666666666666666, 'overall_f1': 0.8, 'overall_accuracy': 0.9766277128547579}
#  98%|██████████████████████████████████████████▏| 49/50 [00:50<00:01,  1.08s/it]/home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Text:  let 's collect data for this polymer sample
# Predictions:  task_no: task_1; sample_name: polymer
# Targets:  task_no: task_1; sample_name: polymer
# Predicted Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'B-SAMPLE_NAME', 'O']
# True Token Class:  ['O', 'O', 'O', 'O', 'O', 'O', 'B-SAMPLE_NAME', 'O']
# =====================================================================
#
# {'ANGLE': {'precision': 1.0, 'recall': 0.7777777777777778, 'f1': 0.8750000000000001, 'number': 18}, 'EXPOSURE_TIME': {'precision': 1.0, 'recall': 0.6428571428571429, 'f1': 0.782608695652174, 'number': 14}, 'SAMPLE_NAME': {'precision': 1.0, 'recall': 0.5454545454545454, 'f1': 0.7058823529411764, 'number': 11}, 'overall_precision': 1.0, 'overall_recall': 0.6744186046511628, 'overall_f1': 0.8055555555555556, 'overall_accuracy': 0.9769357495881383}
# 100%|███████████████████████████████████████████| 50/50 [00:51<00:00,  1.03s/it]
# /home/w02/anaconda3/envs/venv_task/lib/python3.9/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# 0.1 degree
# ['task_no: task_1', 'angle: 0.1']
# {'task_no: task_1', 'angle: 0.1'}
# We want to look at this perovskite to understand its structure. We think 5 seconds of exposure should be sufficient. Theta of 0.2 would be good.
# ['task_no: task_1', 'sample_name: perovskite']
# {'task_no: task_1', 'sample_name: perovskite'}
# Token indices sequence length is longer than the specified maximum sequence length for this model (44 > 40). Running this sequence through the model will result in indexing errors
# If a material exhibits a spacing between crystal lattice planes d of 6, what does this correspond to in terms of the reciprocal/Fourier space scattering vector q?
# ['task_no: task_2']
# {'task_no: task_2'}
# /data/Muzamil/projects/my_project/bnl_task

# %%
############
# PLEASE NOTE THAT:
# Model performance to extract entities on short command is good. However, for longer input commands, it lacks to extract required entities.
# The reason is the lack of training dataset. (SEE result1 vs result2)
####


from TaskRecognition.rec_model import ExtractNER

ex_feature = ExtractNER()

query = "The exposure time for this experiment is set at 8 seconds."
query2 = "We want to look at this perovskite to understand its structure. We think 5 seconds of exposure should be sufficient. Theta of 0.2 would be good."
query3 = "When the reciprocal space scattering vector q peaks at 1, what does this imply for the interplanar spacing d?"

result1 = ex_feature.predict_ner(query)
result2 = ex_feature.predict_ner(query2)
result3 = ex_feature.predict_ner(query3)

print(result1)
print("\n")
print(result2)
print("\n")
print(result3)
# Out:
# {'input': 'the exposure time for this experiment is set at 8 seconds.', 'ner': [{'exposure_time': '8'}, {'task_no': 'task_1'}]}
#
#
# {'input': 'we want to look at this perovskite to understand its structure. we think 5 seconds of exposure should be sufficient. theta of 0.2 would be good.', 'ner': [{'sample_name': 'perovskite'}, {'task_no': 'task_1'}]}
#
#
# {'input': 'when the reciprocal space scattering vector q peaks at 1, what does this imply for the interplanar spacing d?', 'ner': [{'task_no': 'task_2'}]}

# %% [markdown]
# ### **Task 2**

# %% [markdown]
# Please refer to the link given below for the `task 2` implementation.
#
# **Task 2 Colab URL:** https://colab.research.google.com/drive/1v_vbcmsYiUP_RzkHGFYUZqwU4TJavFy5

# %% [markdown]
# ## Program main assistant
#
# In the following script I provide a simple demo to understand the woking and flow of the assistant program.
#
# - Given user query, it first recognize the intent `(task_no)`.
# - A sample demo is given for `task 1`

# %%
from TaskRecognition.rec_model import ExtractNER
from task1_main import task1_bot

if __name__ == '__main__':
    ex_feature = ExtractNER()

    # query = "If q is 1, and the wavelength lambda λ is 1, what is the scattering angle θ in degree? What is the d spacing?"
    # query = "If a material exhibits a spacing between crystal lattice planes d of 6, what does this correspond to in terms of the reciprocal/Fourier space scattering vector q?"
    query = "We want to look at this perovskite to understand its structure. We think 5 seconds of exposure should be sufficient. Theta of 0.2 would be good."

    result = ex_feature.predict_ner(query)
    print(result['ner'])

    task_no = ""
    for ner_obj in result['ner']:
        if 'task_no' in ner_obj:
            task_no = ner_obj["task_no"]
            break

    # Run task based on the intent.
    if task_no:
        if task_no == "task_1":
            task1_bot(ex_feature, result['ner'])
            pass
        if task_no == "task_2":
            print("Performing task 2")
# Out:
# [{'sample_name': 'perovskite'}, {'task_no': 'task_1'}]
# Processing sample info. sample_name: perovskite, exposure_time: , angle
# What should be the sample exposure time and incident angle?:  5 seconds exposure time and angle should be 0.5 degree
# Running experiments with sample_name: perovskite, exposure_time: 5, and incident angle of 0.5

# %% [markdown]
# As you can see from the above output, the model is not very good at extracting all the informations from a large query. This is due to the lack of training data samples.
#
# - Adding more training samples would results in more better accuracy and performance.
